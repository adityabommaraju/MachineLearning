# %%
## Import Tensorflow

import tensorflow as tf
from tensorflow.keras import models, layers
from matplotlib import pyplot as plt

# %%
#Global Variables

IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
#Import Dataset

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names

# %%
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
#Visualize the data

plt.figure(figsize=(15,15))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i].numpy()])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size,seed=12)
    
    train_size = int(train_split*ds_size)
    val_size = int(val_split*ds_size)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds,val_ds,test_ds

# %%
# Train Test Split

train_ds,val_ds,test_ds = get_dataset_partitions_tf(dataset)

# %%
#Perform caching and prefetch to improve the performance

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
#Resize and Rescaling

resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
#Data Augmentation

data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
# Model Building

input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation="relu", input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(n_classes, activation="softmax"),    
])

model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 128s 2s/step - loss: 0.8998 - accuracy: 0.4853 - val_loss: 0.8343 - val_accuracy: 0.5312
# Epoch 2/50
# 54/54 [==============================] - 119s 2s/step - loss: 0.7905 - accuracy: 0.6520 - val_loss: 0.5614 - val_accuracy: 0.8274
# Epoch 3/50
# 54/54 [==============================] - 131s 2s/step - loss: 0.6085 - accuracy: 0.7529 - val_loss: 0.4623 - val_accuracy: 0.8021
# Epoch 4/50
# 54/54 [==============================] - 110s 2s/step - loss: 0.3928 - accuracy: 0.8462 - val_loss: 0.2514 - val_accuracy: 0.9115
# Epoch 5/50
# 54/54 [==============================] - 107s 2s/step - loss: 0.2454 - accuracy: 0.9049 - val_loss: 0.2149 - val_accuracy: 0.9427
# Epoch 6/50
# 54/54 [==============================] - 121s 2s/step - loss: 0.1914 - accuracy: 0.9266 - val_loss: 0.5634 - val_accuracy: 0.7396
# Epoch 7/50
# 54/54 [==============================] - 119s 2s/step - loss: 0.1651 - accuracy: 0.9331 - val_loss: 0.1864 - val_accuracy: 0.9271
# Epoch 8/50
# 54/54 [==============================] - 121s 2s/step - loss: 0.1178 - accuracy: 0.9601 - val_loss: 0.1265 - val_accuracy: 0.9531
# Epoch 9/50
# 54/54 [==============================] - 117s 2s/step - loss: 0.1373 - accuracy: 0.9507 - val_loss: 0.0965 - val_accuracy: 0.9688
# Epoch 10/50
# 54/54 [==============================] - 118s 2s/step - loss: 0.1371 - accuracy: 0.9425 - val_loss: 0.1752 - val_accuracy: 0.9479
# Epoch 11/50
# 54/54 [==============================] - 121s 2s/step - loss: 0.1251 - accuracy: 0.9536 - val_loss: 0.0784 - val_accuracy: 0.9583
# Epoch 12/50
# 54/54 [==============================] - 123s 2s/step - loss: 0.0891 - accuracy: 0.9660 - val_loss: 0.1208 - val_accuracy: 0.9479
# Epoch 13/50
# 54/54 [==============================] - 111s 2s/step - loss: 0.0767 - accuracy: 0.9724 - val_loss: 0.3005 - val_accuracy: 0.9271
# Epoch 14/50
# 54/54 [==============================] - 106s 2s/step - loss: 0.1124 - accuracy: 0.9554 - val_loss: 0.1602 - val_accuracy: 0.9115
# Epoch 15/50
# 54/54 [==============================] - 106s 2s/step - loss: 0.0923 - accuracy: 0.9677 - val_loss: 0.0640 - val_accuracy: 0.9792
# Epoch 16/50
# 54/54 [==============================] - 106s 2s/step - loss: 0.0806 - accuracy: 0.9683 - val_loss: 0.1704 - val_accuracy: 0.9375
# Epoch 17/50
# 54/54 [==============================] - 122s 2s/step - loss: 0.0533 - accuracy: 0.9836 - val_loss: 0.2602 - val_accuracy: 0.9115
# Epoch 18/50
# 54/54 [==============================] - 118s 2s/step - loss: 0.0495 - accuracy: 0.9824 - val_loss: 0.1543 - val_accuracy: 0.9688
# Epoch 19/50
# 54/54 [==============================] - 122s 2s/step - loss: 0.0846 - accuracy: 0.9660 - val_loss: 0.1788 - val_accuracy: 0.9345
# Epoch 20/50
# 54/54 [==============================] - 118s 2s/step - loss: 0.0914 - accuracy: 0.9689 - val_loss: 0.0877 - val_accuracy: 0.9688
# Epoch 21/50
# 54/54 [==============================] - 125s 2s/step - loss: 0.0538 - accuracy: 0.9797 - val_loss: 0.1243 - val_accuracy: 0.9479
# Epoch 22/50
# 54/54 [==============================] - 120s 2s/step - loss: 0.0525 - accuracy: 0.9830 - val_loss: 0.0695 - val_accuracy: 0.9688
# Epoch 23/50
# 54/54 [==============================] - 120s 2s/step - loss: 0.0502 - accuracy: 0.9818 - val_loss: 0.2593 - val_accuracy: 0.9010
# Epoch 24/50
# 54/54 [==============================] - 117s 2s/step - loss: 0.0400 - accuracy: 0.9847 - val_loss: 0.1755 - val_accuracy: 0.9479
# Epoch 25/50
# 54/54 [==============================] - 124s 2s/step - loss: 0.0720 - accuracy: 0.9742 - val_loss: 0.1134 - val_accuracy: 0.9688
# Epoch 26/50
# 54/54 [==============================] - 125s 2s/step - loss: 0.0311 - accuracy: 0.9890 - val_loss: 0.0387 - val_accuracy: 0.9896
# Epoch 27/50
# 54/54 [==============================] - 121s 2s/step - loss: 0.0477 - accuracy: 0.9826 - val_loss: 0.0693 - val_accuracy: 0.9792
# Epoch 28/50
# 54/54 [==============================] - 124s 2s/step - loss: 0.0540 - accuracy: 0.9795 - val_loss: 0.1165 - val_accuracy: 0.9524
# Epoch 29/50
# 54/54 [==============================] - 126s 2s/step - loss: 0.0769 - accuracy: 0.9711 - val_loss: 0.0360 - val_accuracy: 0.9792
# Epoch 30/50
# 54/54 [==============================] - 131s 2s/step - loss: 0.0629 - accuracy: 0.9789 - val_loss: 0.1360 - val_accuracy: 0.9688
# Epoch 31/50
# 54/54 [==============================] - 124s 2s/step - loss: 0.0472 - accuracy: 0.9824 - val_loss: 0.1087 - val_accuracy: 0.9531
# Epoch 32/50
# 54/54 [==============================] - 118s 2s/step - loss: 0.0358 - accuracy: 0.9873 - val_loss: 0.0704 - val_accuracy: 0.9688
# Epoch 33/50
# 54/54 [==============================] - 129s 2s/step - loss: 0.0375 - accuracy: 0.9888 - val_loss: 0.1111 - val_accuracy: 0.9792
# Epoch 34/50
# 54/54 [==============================] - 128s 2s/step - loss: 0.0409 - accuracy: 0.9873 - val_loss: 0.2150 - val_accuracy: 0.9167
# Epoch 35/50
# 54/54 [==============================] - 123s 2s/step - loss: 0.0554 - accuracy: 0.9818 - val_loss: 0.1178 - val_accuracy: 0.9531
# Epoch 36/50
# 54/54 [==============================] - 119s 2s/step - loss: 0.1175 - accuracy: 0.9566 - val_loss: 0.0759 - val_accuracy: 0.9643
# Epoch 37/50
# 54/54 [==============================] - 111s 2s/step - loss: 0.1626 - accuracy: 0.9401 - val_loss: 0.0961 - val_accuracy: 0.9688
# Epoch 38/50
# 54/54 [==============================] - 121s 2s/step - loss: 0.0322 - accuracy: 0.9884 - val_loss: 0.0796 - val_accuracy: 0.9740
# Epoch 39/50
# 54/54 [==============================] - 107s 2s/step - loss: 0.0501 - accuracy: 0.9826 - val_loss: 0.0557 - val_accuracy: 0.9792
# Epoch 40/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0260 - accuracy: 0.9930 - val_loss: 0.0569 - val_accuracy: 0.9740
# Epoch 41/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0267 - accuracy: 0.9894 - val_loss: 0.0347 - val_accuracy: 0.9844
# Epoch 42/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0252 - accuracy: 0.9941 - val_loss: 0.1339 - val_accuracy: 0.9583
# Epoch 43/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0157 - accuracy: 0.9941 - val_loss: 0.0701 - val_accuracy: 0.9688
# Epoch 44/50
# 54/54 [==============================] - 124s 2s/step - loss: 0.0251 - accuracy: 0.9900 - val_loss: 0.0134 - val_accuracy: 0.9940
# Epoch 45/50
# 54/54 [==============================] - 116s 2s/step - loss: 0.0261 - accuracy: 0.9906 - val_loss: 0.0362 - val_accuracy: 0.9792
# Epoch 46/50
# 54/54 [==============================] - 128s 2s/step - loss: 0.0396 - accuracy: 0.9853 - val_loss: 0.0419 - val_accuracy: 0.9821
# Epoch 47/50
# 54/54 [==============================] - 112s 2s/step - loss: 0.0216 - accuracy: 0.9913 - val_loss: 0.0701 - val_accuracy: 0.9740
# Epoch 48/50
# 54/54 [==============================] - 131s 2s/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 49/50
# 54/54 [==============================] - 118s 2s/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.0556 - val_accuracy: 0.9792
# Epoch 50/50
# 54/54 [==============================] - 125s 2s/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0603 - val_accuracy: 0.9792

# %%
history
# Out:
# history

# %%
EPOCHS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 EPOCHS
#
# NameError: name 'EPOCHS' is not defined
